# %% [markdown]
# <a href="https://colab.research.google.com/github/proteus21/DATA-SCIENCE-STUDY/blob/main/Machine%20Learning/04_Selection_model/01_underfitting_overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To install scikit-learn library use command below
# Aby zainstalować bibliotekę scikit-learn, użyj polecenia poniżej:
#
# **!pip install scikit-learn**

# %% [markdown]
# In order to update to newest scikit-learn library, use command below
#
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
#
# **!pip install --upgrade scikit-learn**
#
# ### Contest:
# 1. [Import library](#a0)
# 2. [Metrics - Binary classification](#a1)
#     1. [Accuracy - accurancy classification ](#a2)
#     2. [Confiusion matrix](#a3)
#     3. [Curve ROC](#a4)
# 3. [Matrics - multiclass classification](#a5)
#     1. [Accuracy - accurancy classification](#a6)
#     2. [Confiusion matrix](#a7)
#     3. [Classification report](#a8)
#
#
#
#
# ### Metryki - Problem klasyfikacji:
# 1. [Import bibliotek](#a0)
# 2. [Metryki - Klasyfikacja binarna](#a1)
#     1. [Accuracy - dokładność klasyfikacji](#a2)
#     2. [Macierz konfuzji/pomyłek](#a3)
#     3. [Krzywa ROC](#a4)
# 3. [Metryki - Klasyfikacja wieloklasowa](#a5)
#     1. [Accuracy - dokładność klasyfikacji](#a6)
#     2. [Macierz konfuzji/pomyłek](#a7)
#     3. [Raport klasyfikacji](#a8)

# %% [markdown]
# In order to update to newest scikit-learn library, use command below
#
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
#
# **!pip install --upgrade scikit-learn**
#
# ### Contest:
# 1. [Import library](#0)
# 2. [Generate data](#1)
# 3. [Data Visualition](#2)
# 4. [Devided into traning and testing set](#3)
# 5. [Wisualition of training and tests ](#4)
# 6. [Underfitting - Logistic regresji](#5)
# 7. [Underfitting - Decision ](#6)
# 8. [overfitting sample](#7)
#
#
#
#
# ### Metryki - Problem klasyfikacji:
# 1. [Import bibliotek](#0)
# 2. [Wygenerowanie danych](#1)
# 3. [Wizualizacja danych](#2)
# 4. [Podział na zbiór treningowy i testowy](#3)
# 5. [Wizualizacja zbioru treningowego i testowego](#4)
# 6. [Niedouczenie - Regresja Logistyczna](#5)
# 7. [Niedouczenie - Drzewa Decyzyjne](#6)
# 8. [Przykład przeuczenia](#7)

# %% [markdown]
# ### <a name='0'></a> Import library / Import bibliotek

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import plotly.express as px

np.random.seed(42)
sns.set(font_scale =1.3)

# %% [markdown]
# ### <a name='1'> Wygenerowanie danych / Data generate </a>

# %%
# n_samples=200
raw_data = make_moons(n_samples=2000, noise=0.25, random_state=42)
data=raw_data[0]
target=raw_data[1]
print(f'{data[:5]}\n')
print(f'{target[:5]}')
# Out:
# [[ 1.58230488  0.36687604]
#  [ 0.32765354  0.98236569]
#  [ 0.48826986 -0.2467652 ]
#  [-0.93742051 -0.02942909]
#  [ 0.63439695 -0.41222371]]
#
# [1 0 1 0 1]

# %%
df=pd.DataFrame(data=np.c_[data, target], columns=['x1','x2', 'target'])
df.head()
# Out:
#          x1        x2  target
# 0  1.582305  0.366876     1.0
# 1  0.327654  0.982366     0.0
# 2  0.488270 -0.246765     1.0
# 3 -0.937421 -0.029429     0.0
# 4  0.634397 -0.412224     1.0

# %% [markdown]
# ### <a name='2'> Wizualizacja danych / Data visualzation </a>

# %%
plt.figure(figsize=(10,8))
plt.scatter(data[:,0], data[:,1], c=target, cmap='viridis')
plt.title('Klasyfikacja-modele')
plt.show()

# %% [markdown]
# ### <a name='3'> Podział na zbior treningowy i testowy/   Division into treining and testing set</a>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3)

print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (1400, 2)
# X_test shape: (600, 2)
# y_train shape: (1400,)
# y_test shape: (600,)

# %% [markdown]
# ### <a name='4'> Wizualizacja zbioru treningowego i testowego/   Visualisation training and testing set</a>

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='RdYlBu', label = 'training_set')
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='RdYlBu', marker='x', alpha=0.5, label='test_set')
plt.title('Zbiór treningowy i testowy')
plt.legend()
plt.show()

# %% [markdown]
# ### <a name='5'> Niedouczenie - Regresja Logistyczna/   Underfitting - Logistic regresion</a>

# %%
from sklearn.linear_model import LogisticRegression

classifier=LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#ZBIÓR TRENNINGOWY

from mlxtend.plotting import plot_decision_regions

plt.figure(figsize=(10, 8))
plot_decision_regions(X_train, y_train, clf=classifier)
plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-3dabc5ee75f8> in <module>
#       4
#       5 plt.figure(figsize=(10, 8))
# ----> 6 plot_decision_regions(X_train, y_train, clf=classifier)
#       7 plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
#       8 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %% [markdown]
# # Zbiór testowy

# %%
plt.figure(figsize=(10, 8))
plot_decision_regions(X_test, y_test, classifier)
plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-16c772ae1c00> in <module>
#       1 plt.figure(figsize=(10, 8))
# ----> 2 plot_decision_regions(X_test, y_test, classifier)
#       3 plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
#       4 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %% [markdown]
# ### <a name='6'> Niedouczenie - Drzewa decyzyjne/   Underfitting - Decision Tree</a>

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier(max_depth=1)
classifier.fit(X_train, y_train)

plt.figure(figsize=(10, 8))
plot_decision_regions(X_train, y_train, clf=classifier)
plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a688aeecd0fc> in <module>
#       5
#       6 plt.figure(figsize=(10, 8))
# ----> 7 plot_decision_regions(X_train, y_train, clf=classifier)
#       8 plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
#       9 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %%
plt.figure(figsize=(10, 8))
plot_decision_regions(X_test, y_test, classifier)
plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-16c772ae1c00> in <module>
#       1 plt.figure(figsize=(10, 8))
# ----> 2 plot_decision_regions(X_test, y_test, classifier)
#       3 plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
#       4 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %% [markdown]
# ### <a name='7'> Przeuczenie - Drzewa decyzyjne/   Overfitting - Decision Tree</a>

# %%
# !pip install mlxtend
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)

plt.figure(figsize=(10, 8))
plot_decision_regions(X_train, y_train, classifier)
plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-1c5fdbcc3d8c> in <module>
#       3
#       4 plt.figure(figsize=(10, 8))
# ----> 5 plot_decision_regions(X_train, y_train, classifier)
#       6 plt.title(f'Zbiór treningowy: dokładność {classifier.score(X_train, y_train):.4f}')
#       7 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...

# %%
#plt.figure(figsize=(10, 8))
fig, ax = plt.subplots(figsize=(10, 6))
plot_decision_regions(X_test, y_test, classifier,legend=2, ax=ax)
plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-a649740fbda9> in <module>
#       1 #plt.figure(figsize=(10, 8))
#       2 fig, ax = plt.subplots(figsize=(10, 6))
# ----> 3 plot_decision_regions(X_test, y_test, classifier,legend=2, ax=ax)
#       4 plt.title(f'Zbiór testowy: dokładność {classifier.score(X_test, y_test):.4f}')
#       5 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# ...
