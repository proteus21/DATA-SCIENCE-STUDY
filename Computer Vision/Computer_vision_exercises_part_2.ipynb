# %% [markdown]
# <a href="https://colab.research.google.com/github/proteus21/DATA-SCIENCE-STUDY/blob/main/Computer%20Vision/Computer_vision_exercises_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision - OpenCV - Second Task (25 minutes)
# @author Tomasz Skrzypczyk

# %% [markdown]
# Here are some OpenCv exercises, you are asked to use the internet ( [official documentation](https://docs.opencv.org/4.x/)) to find the methods you need.

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/Spot_the_difference.png")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x353 at 0x7FF43108B9D0>

# %%
# find out the image's shape
image.shape
# Out:
# (353, 640, 3)

# %%
# now split the image in two by half
h, w, channels = image.shape

image_left = image[:, :w//2]
image_right = image[:, w//2:]

# %%
cv2_imshow(image_left)
# Out:
# <PIL.Image.Image image mode=RGB size=320x353 at 0x7FF43108B6D0>

# %%
cv2_imshow(image_right)
# Out:
# <PIL.Image.Image image mode=RGB size=320x353 at 0x7FF43108BA90>

# %%
# calculate the difference between images (use numpy only)
image_diff = image_left-image_right
cv2_imshow(image_diff)
# Out:
# <PIL.Image.Image image mode=RGB size=320x353 at 0x7FF43108BF10>

# %%
import numpy as np
# apply erosion with kernel (3,3)
kernel = np.ones((3,3),np.uint8)

image_diff_eroded = cv2.erode(image,kernel)
cv2_imshow(image_diff_eroded)
# Out:
# <PIL.Image.Image image mode=RGB size=640x353 at 0x7FF43106AA60>

# %%
# convert image to greyscale [or to grayscale :)]
image_diff_grey = cv2.cvtColor(image_diff_eroded, cv2.COLOR_BGR2GRAY)

# %%
# use binary thresholding, set thresh value to 10
_, thresh = cv2.threshold(image_diff_grey, 10, 255,0)
cv2_imshow(tresh)
# Out:
# <PIL.Image.Image image mode=L size=640x353 at 0x7FF43108B880>

# %%
# find contours in the image source:https://docs.opencv.org/4.x/d4/d73/tutorial_py_contours_begin.html
contours, hierarchy = cv2.findContours(image_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9423b6a53b14> in <module>
#       1 # find contours in the image source:https://docs.opencv.org/4.x/d4/d73/tutorial_py_contours_begin.html
# ----> 2 contours, hierarchy = cv2.findContours(image_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# NameError: name 'cv2' is not defined

# %%
# and draw them on the left image
image_with_contours = cv2.drawContours(image_left, contours,-1, (0,255,0), 3)
cv2_imshow(image_with_contours)
# Out:
# <PIL.Image.Image image mode=RGB size=320x353 at 0x7FF43108B580>
